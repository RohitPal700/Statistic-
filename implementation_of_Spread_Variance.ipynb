# %%
data =[2,3,4,5,8,9,12,40,41,15]

# %%
data
# Out:
# [2, 3, 4, 5, 8, 9, 12, 40, 41, 15]

# %%
#here we find range 
max(data) -min(data)
# Out:
# 39

# %%
import numpy as np

# %%
#here we find quartile of percitile 
np.percentile(data,[0,25,50,75,100])
# Out:
# array([ 2.  ,  4.25,  8.5 , 14.25, 41.  ])

# %%
# Inter quartile range (IQR)= Q3-Q1
5-3
# Out:
# 2

# %%
import seaborn as sns

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
#variance 
np.var(data)
# Out:
# np.float64(191.69000000000003)

# %%
np.std(data)
# Out:
# np.float64(13.8452157801892)

# %%
import statistics

# %%
statistics.variance(data) # it gives sample variance >n-1
# Out:
# 212.98888888888888

# %%
statistics.pvariance(data) # it gives population  variance >n-1
# Out:
# 191.69
