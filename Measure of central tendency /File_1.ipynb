# %%
# Measure of central Tendency

# %%
#Mean/Average 

age = [28,56,35,28,76,89]

# %%
(28+56+35+28+76+89)/6
# Out:
# 52.0

# %%
import numpy as np

# %%
np.mean(age)
# Out:
# np.float64(52.0)

# %%
# Median

nums=[4,5,6,4,4,5,2,1,4,]
np.median(nums)
# Out:
# np.float64(4.0)

# %%
#mode

num=[1,3,4,5,6,3,32,345,66,3,3,3]

# %%
from scipy import stats

# %%
stats.mode(num)
# Out:
# ModeResult(mode=np.int64(3), count=np.int64(5))

# %%
import statistics

# %%
statistics.mode(num)
# Out:
# 3

# %%
#Check outlier effects mean and does'nt effect median

height = [160,120,125,340,150]
np.mean(height)
# Out:
# np.float64(179.0)

# %%
np.median(height)
# Out:
# np.float64(150.0)

# %%
# After outlier

# %%
height = [1600,120,125,340,150]
np.mean(height)
# Out:
# np.float64(467.0)

# %%
height = [1600,120,125,340,150]
np.median(height)
# Out:
# np.float64(150.0)
